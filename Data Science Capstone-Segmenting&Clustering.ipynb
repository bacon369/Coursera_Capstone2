# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wiki_html = requests.get(url).text
soup = BeautifulSoup(wiki_html, 'html.parser')
data = []
for tr in soup.tbody.find_all('tr'):
    data.append([ td.get_text().strip() for td in tr.find_all('td')])

# %%
df = pd.DataFrame(data, columns=['PostalCode','Borough','Neighborhood'])

# %%
df.head()
# Out:
#   PostalCode       Borough      Neighborhood
# 0       None          None              None
# 1        M1A  Not assigned
# 2        M2A  Not assigned
# 3        M3A    North York         Parkwoods
# 4        M4A    North York  Victoria Village

# %%
indexNames = df[(df['Borough'] == "Not assigned")].index
df.drop(indexNames,inplace=True) #drop boroughs with value Not assigned
df.dropna(inplace=True)
df=df.groupby(['PostalCode','Borough'])['Neighborhood'].apply(', '.join).reset_index()

# %%
df.head(10)
# Out:
#   PostalCode      Borough                                       Neighborhood
# 0        M1B  Scarborough                                    Malvern / Rouge
# 1        M1C  Scarborough           Rouge Hill / Port Union / Highland Creek
# 2        M1E  Scarborough                Guildwood / Morningside / West Hill
# 3        M1G  Scarborough                                             Woburn
# 4        M1H  Scarborough                                          Cedarbrae
# 5        M1J  Scarborough                                Scarborough Village
# 6        M1K  Scarborough      Kennedy Park / Ionview / East Birchmount Park
# 7        M1L  Scarborough                  Golden Mile / Clairlea / Oakridge
# 8        M1M  Scarborough  Cliffside / Cliffcrest / Scarborough Village West
# 9        M1N  Scarborough                       Birch Cliff / Cliffside West

# %%
def clean_tbl(data):
    if data['Neighborhood']=='Not assigned':
        var=data['Borough']
    else:
        var=data['Neighborhood']
    return var
df['Neighborhood_new']=df.apply(clean_tbl,axis='columns')

# %%
df.head(10)
# Out:
#   PostalCode      Borough                                       Neighborhood  \
# 0        M1B  Scarborough                                    Malvern / Rouge
# 1        M1C  Scarborough           Rouge Hill / Port Union / Highland Creek
# 2        M1E  Scarborough                Guildwood / Morningside / West Hill
# 3        M1G  Scarborough                                             Woburn
# 4        M1H  Scarborough                                          Cedarbrae
# 5        M1J  Scarborough                                Scarborough Village
# 6        M1K  Scarborough      Kennedy Park / Ionview / East Birchmount Park
# 7        M1L  Scarborough                  Golden Mile / Clairlea / Oakridge
# 8        M1M  Scarborough  Cliffside / Cliffcrest / Scarborough Village West
# 9        M1N  Scarborough                       Birch Cliff / Cliffside West
#
#                                     Neighborhood_new
# 0                                    Malvern / Rouge
# 1           Rouge Hill / Port Union / Highland Creek
# 2                Guildwood / Morningside / West Hill
# 3                                             Woburn
# 4                                          Cedarbrae
# 5                                Scarborough Village
# 6      Kennedy Park / Ionview / East Birchmount Park
# 7                  Golden Mile / Clairlea / Oakridge
# 8  Cliffside / Cliffcrest / Scarborough Village West
# 9                       Birch Cliff / Cliffside West

# %%
df.drop(columns='Neighborhood')
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A  Downtown Toronto
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                       Neighborhood_new
# 0                                      Malvern / Rouge
# 1             Rouge Hill / Port Union / Highland Creek
# 2                  Guildwood / Morningside / West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6        Kennedy Park / Ionview / East Birchmount Park
# 7                    Golden Mile / Clairlea / Oakridge
# 8    Cliffside / Cliffcrest / Scarborough Village West
# 9                         Birch Cliff / Cliffside West
# 10   Dorset Park / Wexford Heights / Scarborough To...
# 11                                  Wexford / Maryvale
# 12                                           Agincourt
# 13           Clarks Corners / Tam O'Shanter / Sullivan
# 14   Milliken / Agincourt North / Steeles East / L'...
# 15                      Steeles West / L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                      Fairview / Henry Farm / Oriole
# 19                                     Bayview Village
# 20                           York Mills / Silver Hills
# 21                            Willowdale / Newtonbrook
# 22                                          Willowdale
# 23                                     York Mills West
# 24                                          Willowdale
# 25                                           Parkwoods
# 26                                           Don Mills
# 27                                           Don Mills
# 28   Bathurst Manor / Wilson Heights / Downsview North
# 29                    Northwood Park / York University
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                       Dufferin / Dovercourt Village
# 77                           Little Portugal / Trinity
# 78      Brockton / Parkdale Village / Exhibition Place
# 79          North Park / Maple Leaf Park / Upwood Park
# 80   Del Ray / Mount Dennis / Keelsdale and Silvert...
# 81                      Runnymede / The Junction North
# 82                      High Park / The Junction South
# 83                             Parkdale / Roncesvalles
# 84                                 Runnymede / Swansea
# 85        Queen's Park / Ontario Provincial Government
# 86               Canada Post Gateway Processing Centre
# 87               Business reply mail Processing CentrE
# 88      New Toronto / Mimico South / Humber Bay Shores
# 89                             Alderwood / Long Branch
# 90    The Kingsway / Montgomery Road  / Old Mill North
# 91   Old Mill South / King's Mill Park / Sunnylea /...
# 92   Mimico NW / The Queensway West / South of Bloo...
# 93                                    Islington Avenue
# 94   West Deane Park / Princess Gardens / Martin Gr...
# 95   Eringate / Bloordale Gardens / Old Burnhamthor...
# 96                                       Humber Summit
# 97                                   Humberlea / Emery
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village / St. Phillips / Martin Grov...
# 101  South Steeles / Silverstone / Humbergate / Jam...
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %%
import pandas as pd
lat_long = pd.read_csv('http://cocl.us/Geospatial_data')
neighborhood_df = df

# %%
lat_long.rename(columns={'Postal Code':'PostalCode'},inplace=True)
df_geocode = pd.merge(neighborhood_df,lat_long,how='left',on='PostalCode')

# %%
df_geocode
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A  Downtown Toronto
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood  \
# 0                                      Malvern / Rouge
# 1             Rouge Hill / Port Union / Highland Creek
# 2                  Guildwood / Morningside / West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6        Kennedy Park / Ionview / East Birchmount Park
# 7                    Golden Mile / Clairlea / Oakridge
# 8    Cliffside / Cliffcrest / Scarborough Village West
# 9                         Birch Cliff / Cliffside West
# 10   Dorset Park / Wexford Heights / Scarborough To...
# 11                                  Wexford / Maryvale
# 12                                           Agincourt
# 13           Clarks Corners / Tam O'Shanter / Sullivan
# 14   Milliken / Agincourt North / Steeles East / L'...
# 15                      Steeles West / L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                      Fairview / Henry Farm / Oriole
# 19                                     Bayview Village
# 20                           York Mills / Silver Hills
# 21                            Willowdale / Newtonbrook
# 22                                          Willowdale
# 23                                     York Mills West
# 24                                          Willowdale
# 25                                           Parkwoods
# 26                                           Don Mills
# 27                                           Don Mills
# 28   Bathurst Manor / Wilson Heights / Downsview North
# 29                    Northwood Park / York University
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                       Dufferin / Dovercourt Village
# 77                           Little Portugal / Trinity
# 78      Brockton / Parkdale Village / Exhibition Place
# 79          North Park / Maple Leaf Park / Upwood Park
# 80   Del Ray / Mount Dennis / Keelsdale and Silvert...
# 81                      Runnymede / The Junction North
# 82                      High Park / The Junction South
# 83                             Parkdale / Roncesvalles
# 84                                 Runnymede / Swansea
# 85        Queen's Park / Ontario Provincial Government
# 86               Canada Post Gateway Processing Centre
# 87               Business reply mail Processing CentrE
# 88      New Toronto / Mimico South / Humber Bay Shores
# 89                             Alderwood / Long Branch
# 90    The Kingsway / Montgomery Road  / Old Mill North
# 91   Old Mill South / King's Mill Park / Sunnylea /...
# 92   Mimico NW / The Queensway West / South of Bloo...
# 93                                    Islington Avenue
# 94   West Deane Park / Princess Gardens / Martin Gr...
# 95   Eringate / Bloordale Gardens / Old Burnhamthor...
# 96                                       Humber Summit
# 97                                   Humberlea / Emery
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village / St. Phillips / Martin Grov...
# 101  South Steeles / Silverstone / Humbergate / Jam...
# 102                                          Northwest
#
#                                       Neighborhood_new   Latitude  Longitude
# 0                                      Malvern / Rouge  43.806686 -79.194353
# 1             Rouge Hill / Port Union / Highland Creek  43.784535 -79.160497
# 2                  Guildwood / Morningside / West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6        Kennedy Park / Ionview / East Birchmount Park  43.727929 -79.262029
# 7                    Golden Mile / Clairlea / Oakridge  43.711112 -79.284577
# 8    Cliffside / Cliffcrest / Scarborough Village West  43.716316 -79.239476
# 9                         Birch Cliff / Cliffside West  43.692657 -79.264848
# 10   Dorset Park / Wexford Heights / Scarborough To...  43.757410 -79.273304
# 11                                  Wexford / Maryvale  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13           Clarks Corners / Tam O'Shanter / Sullivan  43.781638 -79.304302
# 14   Milliken / Agincourt North / Steeles East / L'...  43.815252 -79.284577
# 15                      Steeles West / L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                      Fairview / Henry Farm / Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                           York Mills / Silver Hills  43.757490 -79.374714
# 21                            Willowdale / Newtonbrook  43.789053 -79.408493
# 22                                          Willowdale  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                          Willowdale  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                           Don Mills  43.745906 -79.352188
# 27                                           Don Mills  43.725900 -79.340923
# 28   Bathurst Manor / Wilson Heights / Downsview North  43.754328 -79.442259
# 29                    Northwood Park / York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                       Dufferin / Dovercourt Village  43.669005 -79.442259
# 77                           Little Portugal / Trinity  43.647927 -79.419750
# 78      Brockton / Parkdale Village / Exhibition Place  43.636847 -79.428191
# 79          North Park / Maple Leaf Park / Upwood Park  43.713756 -79.490074
# 80   Del Ray / Mount Dennis / Keelsdale and Silvert...  43.691116 -79.476013
# 81                      Runnymede / The Junction North  43.673185 -79.487262
# 82                      High Park / The Junction South  43.661608 -79.464763
# 83                             Parkdale / Roncesvalles  43.648960 -79.456325
# 84                                 Runnymede / Swansea  43.651571 -79.484450
# 85        Queen's Park / Ontario Provincial Government  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87               Business reply mail Processing CentrE  43.662744 -79.321558
# 88      New Toronto / Mimico South / Humber Bay Shores  43.605647 -79.501321
# 89                             Alderwood / Long Branch  43.602414 -79.543484
# 90    The Kingsway / Montgomery Road  / Old Mill North  43.653654 -79.506944
# 91   Old Mill South / King's Mill Park / Sunnylea /...  43.636258 -79.498509
# 92   Mimico NW / The Queensway West / South of Bloo...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   West Deane Park / Princess Gardens / Martin Gr...  43.650943 -79.554724
# 95   Eringate / Bloordale Gardens / Old Burnhamthor...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                   Humberlea / Emery  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village / St. Phillips / Martin Grov...  43.688905 -79.554724
# 101  South Steeles / Silverstone / Humbergate / Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 6 columns]

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

import geopy # install it in Anaconda Prompt
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !pip install folium

from IPython.display import Image # will upload screenshots later
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/fd/a0/ccb3094026649cda4acd55bf2c3822bb8c277eb11446d13d384e5be35257/folium-0.10.1-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 6.9MB/s eta 0:00:011
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/81/6d/31c83485189a2521a75b4130f1fee5364f772a0375f81afff619004e5237/branca-0.4.0-py3-none-any.whl
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.4.5.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.0 folium-0.10.1

# %%
import folium

# %%
tonbhd = df_geocode
to_data = tonbhd[tonbhd.Borough.str.contains('Toronto')]
to_data.head(10)
# Out:
#    PostalCode          Borough  \
# 37        M4E     East Toronto
# 41        M4K     East Toronto
# 42        M4L     East Toronto
# 43        M4M     East Toronto
# 44        M4N  Central Toronto
# 45        M4P  Central Toronto
# 46        M4R  Central Toronto
# 47        M4S  Central Toronto
# 48        M4T  Central Toronto
# 49        M4V  Central Toronto
#
#                                          Neighborhood  \
# 37                                        The Beaches
# 41                      The Danforth West / Riverdale
# 42                    India Bazaar / The Beaches West
# 43                                    Studio District
# 44                                      Lawrence Park
# 45                                   Davisville North
# 46                                 North Toronto West
# 47                                         Davisville
# 48                       Moore Park / Summerhill East
# 49  Summerhill West / Rathnelly / South Hill / For...
#
#                                      Neighborhood_new   Latitude  Longitude
# 37                                        The Beaches  43.676357 -79.293031
# 41                      The Danforth West / Riverdale  43.679557 -79.352188
# 42                    India Bazaar / The Beaches West  43.668999 -79.315572
# 43                                    Studio District  43.659526 -79.340923
# 44                                      Lawrence Park  43.728020 -79.388790
# 45                                   Davisville North  43.712751 -79.390197
# 46                                 North Toronto West  43.715383 -79.405678
# 47                                         Davisville  43.704324 -79.388790
# 48                       Moore Park / Summerhill East  43.689574 -79.383160
# 49  Summerhill West / Rathnelly / South Hill / For...  43.686412 -79.400049

# %%
to_data.shape
# Out:
# (39, 6)

# %%
CLIENT_ID = 'O3S1RC0NPPA31104YY5LYRMPY45AOYN5WFDL5MENXK4D014K' # Foursquare ID
CLIENT_SECRET = 'CGA4KJUTTTIYLQIS5SIKQZ0I12GTXJGR0NYV4AWOOKYLMHLK' # Foursquare Secret
VERSION = '20180604'
LIMIT = 30
#print('Your credentials:')
#print('CLIENT_ID: ' + CLIENT_ID)
#print('CLIENT_SECRET:' + CLIENT_SECRET)

address = 'Toronto, ON'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

print('Toronto coordinates are {}, {}.'.format(latitude, longitude))

map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)
for lat, lng, label in zip(to_data['Latitude'], to_data['Longitude'], to_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# Toronto coordinates are 43.6534817, -79.3839347.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query = 'Bakery'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Bakery .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=O3S1RC0NPPA31104YY5LYRMPY45AOYN5WFDL5MENXK4D014K&client_secret=CGA4KJUTTTIYLQIS5SIKQZ0I12GTXJGR0NYV4AWOOKYLMHLK&ll=43.6534817,-79.3839347&v=20180604&query=Bakery&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e9e2a1b77af03001be7b8fc'},
#  'response': {'venues': [{'id': '4b9f9b5af964a5206b2e37e3',
#     'name': 'Bakery 18',
#     'location': {'address': '595 Bay St.',
#      'crossStreet': 'at Dundas St. W',
#      'lat': 43.656765349412275,
#      'lng': -79.38354755464013,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656765349412275,
#        'lng': -79.38354755464013}],
#      'distance': 366,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['595 Bay St. (at Dundas St. W)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587423720',
#     'hasPerk': False},
#    {'id': '4c9ca65d54c8a1cd4fe97b4b',
#     'name': 'The Bakery Communications',
#     'location': {'address': '100 King Street West suite 5700',
#      'crossStreet': 'Bay Street',
#      'lat': 43.648099,
#      'lng': -79.381774,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648099,
#        'lng': -79.381774}],
#      'distance': 623,
#      'postalCode': 'M5X 1C7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 King Street West suite 5700 (Bay Street)',
#       'Toronto ON M5X 1C7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587423720',
#     'hasPerk': False},
#    {'id': '53542f20498eb5c7149ecafd',
#     'name': 'Bakery & Kaffee Haus',
#     'location': {'address': '238 Queen Street West',
#      'lat': 43.6500955307706,
#      'lng': -79.39037817435783,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6500955307706,
#        'lng': -79.39037817435783}],
#      'distance': 641,
#      'postalCode': 'M5V 0B5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['238 Queen Street West',
#       'Toronto ON M5V 0B5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587423720',
#     'hasPerk': False},
#    {'id': '57462ae4498efddb24245014',
#     'name': 'Paris Croissant Bakery Cafe',
#     'location': {'address': '595 Bay St',
#      'crossStreet': 'Dundas St West',
#      'lat': 43.656204,
#      'lng': -79.38321,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656204,
#        'lng': -79.38321}],
#      'distance': 308,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['595 Bay St (Dundas St West)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587423720',
#     'hasPerk': False},
#    {'id': '4eadd3dbe5fad025f84c97f4',
#     'name': 'Kin-Kin Bakery & Bubble Tea',
#     'location': {'address': '595 Bay St.',
#      'lat': 43.656198463938644,
#      'lng': -79.38240298717774,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656198463938644,
#        'lng': -79.38240298717774}],
#      'distance': 326,
#      'postalCode': 'M5G 2C2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['595 Bay St.', 'Toronto ON M5G 2C2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587423720',
#     'hasPerk': False},
#    {'id': '4ec4256c722e7658977696c7',
#     'name': 'Prairie Girl Bakery',
#     'location': {'address': '100 King St. W',
#      'crossStreet': 'in First Canadian Place (Concourse Level)',
#      'lat': 43.64833236397115,
#      'lng': -79.38230492443054,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64833236397115,
#        'lng': -79.38230492443054}],
#      'distance': 588,
#      'postalCode': 'M5X 2A1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 King St. W (in First Canadian Place (Concourse Level))',
#       'Toronto ON M5X 2A1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1bc941735',
#       'name': 'Cupcake Shop',
#       'pluralName': 'Cupcake Shops',
#       'shortName': 'Cupcakes',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587423720',
#     'hasPerk': False},
#    {'id': '4d77a23fbc888cfa2217ed73',
#     'name': 'Artisan Bakery and Foods',
#     'location': {'address': '1 King Street West',
#      'crossStreet': 'Yonge',
#      'lat': 43.64901622313234,
#      'lng': -79.37840647629473,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64901622313234,
#        'lng': -79.37840647629473}],
#      'distance': 667,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 King Street West (Yonge)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587423720',
#     'hasPerk': False},
#    {'id': '4e5493f4b0fb1e3684c4284f',
#     'name': 'O&B Artisan',
#     'location': {'address': '176 Yonge St.',
#      'lat': 43.65223538070189,
#      'lng': -79.38000381513287,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65223538070189,
#        'lng': -79.38000381513287}],
#      'distance': 345,
#      'postalCode': 'M5C 2L7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['176 Yonge St.', 'Toronto ON M5C 2L7', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '48334878'},
#     'referralId': 'v-1587423720',
#     'hasPerk': False},
#    {'id': '4afc5b80f964a520e42122e3',
#     'name': 'Fresh Start Coffee Co.',
#     'location': {'address': '655 Bay St',
#      'crossStreet': 'at Elm St',
#      'lat': 43.657377165116216,
#      'lng': -79.38439256972293,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657377165116216,
#        'lng': -79.38439256972293}],
#      'distance': 435,
#      'postalCode': 'M5G 2K4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['655 Bay St (at Elm St)',
#       'Toronto ON M5G 2K4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587423720',
#     'hasPerk': False},
#    {'id': '4b4240b4f964a5200dd025e3',
#     'name': 'Furama',
#     'location': {'address': '100 King St. W',
#      'crossStreet': 'at First Canadian Place',
#      'lat': 43.648439664552484,
#      'lng': -79.38207679893517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648439664552484,
#        'lng': -79.38207679893517}],
#      'distance': 580,
#      'postalCode': 'M5X 1A9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 King St. W (at First Canadian Place)',
#       'Toronto ON M5X 1A9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587423720',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head(10)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...    False
# 1  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 2  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...    False
# 3  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...    False
# 4  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...    False
# 5  [{'id': '4bf58dd8d48988d1bc941735', 'name': 'C...    False
# 6  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 7  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...    False
# 8  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 9  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...    False
#
#                          id                 location.address location.cc  \
# 0  4b9f9b5af964a5206b2e37e3                      595 Bay St.          CA
# 1  4c9ca65d54c8a1cd4fe97b4b  100 King Street West suite 5700          CA
# 2  53542f20498eb5c7149ecafd            238 Queen Street West          CA
# 3  57462ae4498efddb24245014                       595 Bay St          CA
# 4  4eadd3dbe5fad025f84c97f4                      595 Bay St.          CA
# 5  4ec4256c722e7658977696c7                   100 King St. W          CA
# 6  4d77a23fbc888cfa2217ed73               1 King Street West          CA
# 7  4e5493f4b0fb1e3684c4284f                    176 Yonge St.          CA
# 8  4afc5b80f964a520e42122e3                       655 Bay St          CA
# 9  4b4240b4f964a5200dd025e3                   100 King St. W          CA
#
#   location.city location.country                       location.crossStreet  \
# 0       Toronto           Canada                            at Dundas St. W
# 1       Toronto           Canada                                 Bay Street
# 2       Toronto           Canada                                        NaN
# 3       Toronto           Canada                             Dundas St West
# 4       Toronto           Canada                                        NaN
# 5       Toronto           Canada  in First Canadian Place (Concourse Level)
# 6       Toronto           Canada                                      Yonge
# 7       Toronto           Canada                                        NaN
# 8       Toronto           Canada                                  at Elm St
# 9       Toronto           Canada                    at First Canadian Place
#
#    location.distance                          location.formattedAddress  \
# 0                366  [595 Bay St. (at Dundas St. W), Toronto ON, Ca...
# 1                623  [100 King Street West suite 5700 (Bay Street),...
# 2                641  [238 Queen Street West, Toronto ON M5V 0B5, Ca...
# 3                308  [595 Bay St (Dundas St West), Toronto ON, Canada]
# 4                326          [595 Bay St., Toronto ON M5G 2C2, Canada]
# 5                588  [100 King St. W (in First Canadian Place (Conc...
# 6                667   [1 King Street West (Yonge), Toronto ON, Canada]
# 7                345        [176 Yonge St., Toronto ON M5C 2L7, Canada]
# 8                435  [655 Bay St (at Elm St), Toronto ON M5G 2K4, C...
# 9                580  [100 King St. W (at First Canadian Place), Tor...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65676534941227...     43.656765
# 1  [{'label': 'display', 'lat': 43.648099, 'lng':...     43.648099
# 2  [{'label': 'display', 'lat': 43.6500955307706,...     43.650096
# 3  [{'label': 'display', 'lat': 43.656204, 'lng':...     43.656204
# 4  [{'label': 'display', 'lat': 43.65619846393864...     43.656198
# 5  [{'label': 'display', 'lat': 43.64833236397115...     43.648332
# 6  [{'label': 'display', 'lat': 43.64901622313234...     43.649016
# 7  [{'label': 'display', 'lat': 43.65223538070189...     43.652235
# 8  [{'label': 'display', 'lat': 43.65737716511621...     43.657377
# 9  [{'label': 'display', 'lat': 43.64843966455248...     43.648440
#
#    location.lng location.postalCode location.state  \
# 0    -79.383548                 NaN             ON
# 1    -79.381774             M5X 1C7             ON
# 2    -79.390378             M5V 0B5             ON
# 3    -79.383210                 NaN             ON
# 4    -79.382403             M5G 2C2             ON
# 5    -79.382305             M5X 2A1             ON
# 6    -79.378406                 NaN             ON
# 7    -79.380004             M5C 2L7             ON
# 8    -79.384393             M5G 2K4             ON
# 9    -79.382077             M5X 1A9             ON
#
#                           name    referralId venuePage.id
# 0                    Bakery 18  v-1587423720          NaN
# 1    The Bakery Communications  v-1587423720          NaN
# 2         Bakery & Kaffee Haus  v-1587423720          NaN
# 3  Paris Croissant Bakery Cafe  v-1587423720          NaN
# 4  Kin-Kin Bakery & Bubble Tea  v-1587423720          NaN
# 5          Prairie Girl Bakery  v-1587423720          NaN
# 6     Artisan Bakery and Foods  v-1587423720          NaN
# 7                  O&B Artisan  v-1587423720     48334878
# 8       Fresh Start Coffee Co.  v-1587423720          NaN
# 9                       Furama  v-1587423720          NaN
